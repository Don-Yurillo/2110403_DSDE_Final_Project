# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json(r'E:\Works\Intro-to-Data-Science\2110403_DSDE_Final_Project\src\data\db-data\predicted_data.json')
df
# Out:
#              name    affiliation  subject_code  cited_count  \
# 0            Krit       Thailand          2700            1
# 1            Krit  United States          2700            1
# 2       Teerapong       Thailand          2208            1
# 3         Panuwat       Thailand          2208            1
# 4       Teerapong       Thailand          2504            1
# ...           ...            ...           ...          ...
# 300359     Noelia        Unknown          2305           24
# 300360     Adrian        Unknown          2305           24
# 300361   Jonathan        Unknown          2305           24
# 300362    Ailette        Unknown          2305           24
# 300363      Olatz        Unknown          2305           24
#
#                      pub_type  year predict_gender
# 0                        Book  2018              m
# 1                        Book  2018              m
# 2       Conference Proceeding  2018              m
# 3       Conference Proceeding  2018              m
# 4       Conference Proceeding  2018              m
# ...                       ...   ...            ...
# 300359                Journal  2017              f
# 300360                Journal  2017              m
# 300361                Journal  2017              m
# 300362                Journal  2017              f
# 300363                Journal  2017              m
#
# [300364 rows x 7 columns]

# %%
# df = df[df['subject_code'] >= 2200]
# df = df[df['subject_code'] <= 2216]
df['subject_code'] = df['subject_code'].apply(lambda x: str(x)[0:2]+str("00"))
df
# Out:
#              name    affiliation subject_code  cited_count  \
# 0            Krit       Thailand         2700            1
# 1            Krit  United States         2700            1
# 2       Teerapong       Thailand         2200            1
# 3         Panuwat       Thailand         2200            1
# 4       Teerapong       Thailand         2500            1
# ...           ...            ...          ...          ...
# 300359     Noelia        Unknown         2300           24
# 300360     Adrian        Unknown         2300           24
# 300361   Jonathan        Unknown         2300           24
# 300362    Ailette        Unknown         2300           24
# 300363      Olatz        Unknown         2300           24
#
#                      pub_type  year predict_gender
# 0                        Book  2018              m
# 1                        Book  2018              m
# 2       Conference Proceeding  2018              m
# 3       Conference Proceeding  2018              m
# 4       Conference Proceeding  2018              m
# ...                       ...   ...            ...
# 300359                Journal  2017              f
# 300360                Journal  2017              m
# 300361                Journal  2017              m
# 300362                Journal  2017              f
# 300363                Journal  2017              m
#
# [300364 rows x 7 columns]

# %%
df = df[df['subject_code'].str.contains(r"^22")]
df
# Out:
#                name affiliation subject_code  cited_count  \
# 2         Teerapong    Thailand         2200            1
# 3           Panuwat    Thailand         2200            1
# 14      Kiattikhoon    Thailand         2200           21
# 15        Suttichai    Thailand         2200           21
# 16         Benjapon    Thailand         2200           21
# ...             ...         ...          ...          ...
# 298220    Young-Kyu     Unknown         2200           61
# 298233       Pierre       Qatar         2200           29
# 298234      Zhaohui     Unknown         2200           29
# 298235       Carmen     Unknown         2200           29
# 298236        Ilias     Unknown         2200           29
#
#                      pub_type  year predict_gender
# 2       Conference Proceeding  2018              m
# 3       Conference Proceeding  2018              m
# 14                    Journal  2018              m
# 15                    Journal  2018              m
# 16                    Journal  2018              m
# ...                       ...   ...            ...
# 298220                Journal  2017              m
# 298233                Journal  2017              m
# 298234                Journal  2017              f
# 298235                Journal  2017              m
# 298236                Journal  2017              m
#
# [19686 rows x 7 columns]

# %%
df['predict_gender'] = df['predict_gender'].replace(['m','f'], ['male', 'female'])
df
# Out:
#       subject_code predict_gender         name affiliation  cited_count  \
# 0             2200         female       Pitcha    Thailand            0
# 1             2200         female      Wipawee    Thailand            0
# 2             2200         female       Pitcha    Thailand           16
# 3             2200         female     Gridsada    Thailand            0
# 4             2200         female      Krisada    Thailand            1
# ...            ...            ...          ...         ...          ...
# 13957         2200           male      Zongyan   Australia            5
# 13958         2200           male       Zoukel     Algeria            8
# 13959         2200           male      Zwe Yan    Thailand            0
# 13960         2200           male      Zwe Yan    Thailand            0
# 13961         2200           male  and Jiaqian    Thailand           18
#
#                     pub_type  year  count
# 0                    Journal  2023     21
# 1      Conference Proceeding  2020     11
# 2                    Journal  2020      9
# 3                    Journal  2023      8
# 4                    Journal  2022      8
# ...                      ...   ...    ...
# 13957                Journal  2022      1
# 13958                Journal  2022      1
# 13959            Book Series  2023      1
# 13960                Journal  2023      1
# 13961                Journal  2020      1
#
# [13962 rows x 8 columns]

# %%
df =

# %%
df = df.groupby(['subject_code', 'predict_gender']).value_counts().reset_index(name='count')
df.columns = ['subject_code', 'gender', 'count(sub)']
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4648\2029962824.py in ?()
# ----> 1 df = df.groupby(['subject_code', 'predict_gender']).value_counts().reset_index(name='count')
#       2 df.columns = ['subject_code', 'gender', 'count(sub)']
#       3 df
#
# c:\Users\Admins\anaconda3\envs\general\Lib\site-packages\pandas\core\series.py in ?(self, level, drop, name, inplace, allow_duplicates)
#    1766                 else:
#    1767                     name = self.name
#    1768
#    1769             df = self.to_frame(name)
# -> 1770             return df.reset_index(
#    1771                 level=level, drop=drop, allow_duplicates=allow_duplicates
#    1772             )
#    1773         return None
#
# c:\Users\Admins\anaconda3\envs\general\Lib\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6468                     level_values = algorithms.take(
#    6469                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6470                     )
#    6471
# -> 6472                 new_obj.insert(
#    6473                     0,
#    6474                     name,
#    6475                     level_values,
#
# c:\Users\Admins\anaconda3\envs\general\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert count, already exists
